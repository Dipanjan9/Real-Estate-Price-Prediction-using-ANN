# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('kc_house_data.csv')

# %%
df.head(5)
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.describe().transpose()
# Out:
#                  count          mean           std           min  \
# id             21597.0  4.580474e+09  2.876736e+09  1.000102e+06
# price          21597.0  5.402966e+05  3.673681e+05  7.800000e+04
# bedrooms       21597.0  3.373200e+00  9.262989e-01  1.000000e+00
# bathrooms      21597.0  2.115826e+00  7.689843e-01  5.000000e-01
# sqft_living    21597.0  2.080322e+03  9.181061e+02  3.700000e+02
# sqft_lot       21597.0  1.509941e+04  4.141264e+04  5.200000e+02
# floors         21597.0  1.494096e+00  5.396828e-01  1.000000e+00
# waterfront     21597.0  7.547345e-03  8.654900e-02  0.000000e+00
# view           21597.0  2.342918e-01  7.663898e-01  0.000000e+00
# condition      21597.0  3.409825e+00  6.505456e-01  1.000000e+00
# grade          21597.0  7.657915e+00  1.173200e+00  3.000000e+00
# sqft_above     21597.0  1.788597e+03  8.277598e+02  3.700000e+02
# sqft_basement  21597.0  2.917250e+02  4.426678e+02  0.000000e+00
# ...

# %%
plt.figure(figsize=(12,8))
sns.distplot(df['price'])

# %%
sns.countplot(df['bedrooms'])

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df.corr()['price'].sort_values()
# Out:
# zipcode         -0.053402
# id              -0.016772
# long             0.022036
# condition        0.036056
# yr_built         0.053953
# sqft_lot15       0.082845
# sqft_lot         0.089876
# yr_renovated     0.126424
# floors           0.256804
# waterfront       0.266398
# lat              0.306692
# bedrooms         0.308787
# sqft_basement    0.323799
# view             0.397370
# bathrooms        0.525906
# sqft_living15    0.585241
# sqft_above       0.605368
# grade            0.667951
# sqft_living      0.701917
# price            1.000000
# Name: price, dtype: float64

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x ='price',y ='sqft_living',data=df )

# %%
sns.boxenplot(x ='bedrooms',y ='price',data=df)

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='long',y='lat',data=df,hue='price')

# %%
df.sort_values('price',ascending=False).head(20)
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 7245   6762700020  10/13/2014  7700000.0         6       8.00        12050
# 3910   9808700762   6/11/2014  7060000.0         5       4.50        10040
# 9245   9208900037   9/19/2014  6890000.0         6       7.75         9890
# 4407   2470100110    8/4/2014  5570000.0         5       5.75         9200
# 1446   8907500070   4/13/2015  5350000.0         5       5.00         8000
# 1313   7558700030   4/13/2015  5300000.0         6       6.00         7390
# 1162   1247600105  10/20/2014  5110000.0         5       5.25         8010
# 8085   1924059029   6/17/2014  4670000.0         5       6.75         9640
# 2624   7738500731   8/15/2014  4500000.0         5       5.50         6640
# 8629   3835500195   6/18/2014  4490000.0         4       3.00         6430
# 12358  6065300370    5/6/2015  4210000.0         5       6.00         7440
# ...

# %%
len(df)*0.01
# Out:
# 215.97

# %%
new_data=df.sort_values('price',ascending=False).iloc[216:]

# %%
len(new_data)
# Out:
# 21381

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='long',y='lat',data=new_data,hue='price',palette='RdYlGn',alpha=0.3,edgecolor=None)

# %%
sns.boxplot(x='waterfront',y='price',data=df)

# %%
df.head(5)
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
df = df.drop('id',axis=1)

# %%
df.head(5)
# Out:
#          date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  10/13/2014  221900.0         3       1.00         1180      5650     1.0
# 1   12/9/2014  538000.0         3       2.25         2570      7242     2.0
# 2   2/25/2015  180000.0         2       1.00          770     10000     1.0
# 3   12/9/2014  604000.0         4       3.00         1960      5000     1.0
# 4   2/18/2015  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      7        2170            400      1951
# 2           0     0          3      6         770              0      1933
# 3           0     0          5      7        1050            910      1965
# 4           0     0          3      8        1680              0      1987
#
# ...

# %%
df['date']= pd.to_datetime(df['date'])

# %%
df['date'].head(10)
# Out:
# 0   2014-10-13
# 1   2014-12-09
# 2   2015-02-25
# 3   2014-12-09
# 4   2015-02-18
# 5   2014-05-12
# 6   2014-06-27
# 7   2015-01-15
# 8   2015-04-15
# 9   2015-03-12
# Name: date, dtype: datetime64[ns]

# %%
df['year'] = df['date'].apply(lambda date:date.year)

# %%
df['month'] = df['date'].apply(lambda date:date.month)

# %%
df.head(5)
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-10-13  221900.0         3       1.00         1180      5650     1.0
# 1 2014-12-09  538000.0         3       2.25         2570      7242     2.0
# 2 2015-02-25  180000.0         2       1.00          770     10000     1.0
# 3 2014-12-09  604000.0         4       3.00         1960      5000     1.0
# 4 2015-02-18  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  yr_built  yr_renovated  zipcode      lat  \
# 0           0     0          3  ...      1955             0    98178  47.5112
# 1           0     0          3  ...      1951          1991    98125  47.7210
# 2           0     0          3  ...      1933             0    98028  47.7379
# 3           0     0          5  ...      1965             0    98136  47.5208
# 4           0     0          3  ...      1987             0    98074  47.6168
#
# ...

# %%
sns.boxplot(x='price',y='year',data=df)

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
df=df.drop('date',axis=1)

# %%
df.drop('zipcode',axis=1).head()
# Out:
#            id     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520  221900.0         3       1.00         1180      5650     1.0
# 1  6414100192  538000.0         3       2.25         2570      7242     2.0
# 2  5631500400  180000.0         2       1.00          770     10000     1.0
# 3  2487200875  604000.0         4       3.00         1960      5000     1.0
# 4  1954400510  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3  ...        1180              0      1955
# 1           0     0          3  ...        2170            400      1951
# 2           0     0          3  ...         770              0      1933
# 3           0     0          5  ...        1050            910      1965
# 4           0     0          3  ...        1680              0      1987
#
# ...

# %%
X = df.drop('price',axis=1).values

# %%
y= df['price'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=101)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.fit_transform(X_test)

# %%
X_train.shape
# Out:
# (15117, 21)

# %%
X_test.shape
# Out:
# (6480, 21)

# %%
X_train
# Out:
# array([[0.1269347 , 0.3       , 0.08      , ..., 0.00657863, 0.        ,
#         0.72727273],
#        [0.36875106, 0.2       , 0.28      , ..., 0.00288289, 0.        ,
#         0.45454545],
#        [0.33986363, 0.3       , 0.48      , ..., 0.00588823, 1.        ,
#         0.36363636],
#        ...,
#        [0.56820744, 0.1       , 0.2       , ..., 0.00786147, 1.        ,
#         0.27272727],
#        [0.67795106, 0.2       , 0.24      , ..., 0.01557367, 1.        ,
#         0.27272727],
#        [0.27380531, 0.1       , 0.08      , ..., 0.00515118, 1.        ,
#         0.        ]])

# %% [markdown]
# Import Keras Model(Neural Network)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam

# %%
model = Sequential()

model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(1))

model.compile(optimizer='adam',loss='mse')
# Out:
# WARNING:tensorflow:From C:\Users\Dipanjan\Anaconda3\Dipanjan\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %% [markdown]
# Train Model

# %%
model.fit(x=X_train,y=y_train,
          validation_data=(X_test,y_test),
          batch_size=128,epochs=400)
# Out:
# Train on 15117 samples, validate on 6480 samples
# Epoch 1/400
# 15117/15117 [==============================] - 3s 184us/sample - loss: 430234842360.6674 - val_loss: 418895170077.0765
# Epoch 2/400
# 15117/15117 [==============================] - 0s 31us/sample - loss: 428892364652.0596 - val_loss: 414517625560.1778
# Epoch 3/400
# 15117/15117 [==============================] - 1s 38us/sample - loss: 410969417373.4577 - val_loss: 376217922016.3951
# Epoch 4/400
# 15117/15117 [==============================] - 1s 36us/sample - loss: 328032976609.8734 - val_loss: 250722596242.0148
# Epoch 5/400
# 15117/15117 [==============================] - 0s 31us/sample - loss: 175668221844.6348 - val_loss: 119322233029.2148
# Epoch 6/400
# 15117/15117 [==============================] - 1s 41us/sample - loss: 106876921340.2405 - val_loss: 100540196575.7630
# Epoch 7/400
# 15117/15117 [==============================] - 1s 58us/sample - loss: 101719896664.1614 - val_loss: 98275281396.6222
# ...

# %%
model.history.history
# Out:
# {'loss': [430234842360.66736,
#   428892364652.0595,
#   410969417373.4577,
#   328032976609.8734,
#   175668221844.6348,
#   106876921340.24052,
#   101719896664.1614,
#   99604219649.43944,
#   97399410656.29848,
#   95051335525.42119,
#   92694825812.96077,
#   90201490159.62427,
#   87587353252.57022,
#   84855750096.48158,
#   82090310293.05815,
#   79127243533.29364,
#   76084262191.12892,
#   73019891909.5249,
#   69943120239.54807,
#   66916832341.55348,
#   63986734852.28445,
#   61288222448.50486,
#   58747788249.863335,
#   56530162188.091286,
#   54527677257.580734,
#   52879922000.21909,
#   51477148817.53575,
#   50276910513.457436,
#   49223662415.948135,
#   48254385364.49507,
#   47429504294.86485,
#   46621394708.948074,
#   45879742303.86664,
#   45165760545.5982,
#   44548967492.88986,
#   43910690286.69286,
#   43410016934.60237,
#   42808592467.86002,
#   42328908817.81518,
#   41879131555.50334,
#   41368342286.309715,
#   40963635223.30198,
# ...

# %%
A=pd.DataFrame(model.history.history).head()

# %%
A.head()
# Out:
#            loss      val_loss
# 0  4.302348e+11  4.188952e+11
# 1  4.288924e+11  4.145176e+11
# 2  4.109694e+11  3.762179e+11
# 3  3.280330e+11  2.507226e+11
# 4  1.756682e+11  1.193222e+11

# %%
plt.figure(figsize=(12,6))
A.plot()

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,explained_variance_score

# %%
predictions = model.predict(X_test)

# %%
mean_absolute_error(y_test,predictions)
# Out:
# 108063.23537929205

# %%
np.sqrt(mean_squared_error(y_test,predictions))
# Out:
# 175085.79097075135

# %%
explained_variance_score(y_test,predictions)
# Out:
# 0.8020128695606343

# %%
df['price'].mean()
# Out:
# 540296.5735055795

# %%
plt.scatter(y_test,predictions)
plt.plot(y_test,y_test,'r')

# %%
errors = y_test.reshape(6480, 1) - predictions

# %%
sns.distplot(errors)

# %%
single_house = df.drop('price',axis=1).iloc[0]

# %%
single_house = single_house.values

# %%
single_house=scaler.transform(single_house.reshape(-1,21))

# %%
model.predict(single_house)
# Out:
# array([[234161.56]], dtype=float32)

# %%
df.head(1)
# Out:
#            id     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520  221900.0         3        1.0         1180      5650     1.0
#
#    waterfront  view  condition  ...  sqft_basement  yr_built  yr_renovated  \
# 0           0     0          3  ...              0      1955             0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15  year  month
# 0    98178  47.5112 -122.257           1340        5650  2014     10
#
# [1 rows x 22 columns]

# %%
from tensorflow.keras.models import load_model

# %%
model.save('House_Price_Model.h5')
